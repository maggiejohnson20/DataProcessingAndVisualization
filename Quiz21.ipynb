# %% [markdown]
# <a href="https://colab.research.google.com/github/maggiejohnson20/DataProcessingAndVisualization/blob/main/Quiz21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Let's pull the Cholera map that John Snow created.
#
# The visualization below shows the 1854 Cholera outbreak in the city of London, this shows how Snow was able to find the main source of the outbreak.
#
# ![Snow Cholera](https://www.pastmedicalhistory.co.uk/wp-content/uploads/2018/01/1024px-Snow-cholera-map-1.jpg)

# %% [markdown]
# For the second part of the quiz, let's pull something COVID related.
#
# The image below is from the Mayo Clinic Twitter that shows the COVID-19 hotspots back in January 2021.
# ![COVID19Hotspot.jpg](data:image/jpeg;base64,...)
#
# To find the actual link:
# [COVID-19 Jan 21](https://twitter.com/MayoClinic/status/1352345234169016321)
