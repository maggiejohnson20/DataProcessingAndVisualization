# %% [markdown]
# <a href="https://colab.research.google.com/github/maggiejohnson20/DataProcessingAndVisualization/blob/main/Quiz23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![unemployment-rate.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [Fox News Unemployment Rate](https://www.statisticshowto.com/wp-content/uploads/2014/01/unemployment-rate.jpg)

# %% [markdown]
# The image above shows the graph of Fox News report of the Unemployment Rate from when Obama was in office. This graph shows the different months in the year of 2011 but if you notice throughout the months, it jumps just slightly. Now the information gathered was most likely true in that year but the graph needs to be changed a little. To make the points representing the different months easier to pinpoint, they should have made the y-axis, or the percentages of unemployment lower. If they did it correctly then the graph should show that later in the year, the percentage of unemployment should be lower. Which is great.

# %% [markdown]
# ![Omitting-Data.png](data:image/png;base64,...)

# %% [markdown]
# [Omitting Data](https://www.datapine.com/blog/wp-content/uploads/2014/06/Omitting-Data.png)

# %% [markdown]
# The image that I pulled shows a scatter plot of data that shows the data collected throughout the years. What is different about these graphs is the fact that its omitted. Which this can be misleading because it doesn’t show all of the data that has been created throughout the years. It’s just bits and pieces. Even though it can be more pretty to look at, it is not all of the data that they have collected. If they did leave all of the data, then we would be able to see all of the points and curves in the graph.
