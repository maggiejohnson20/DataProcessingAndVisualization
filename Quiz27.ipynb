# %% [markdown]
# <a href="https://colab.research.google.com/github/maggiejohnson20/DataProcessingAndVisualization/blob/main/Quiz27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pa
import matplotlib.pyplot as plt
import seaborn as sns

df = pa.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv')
df.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          NaN      18.88       168.54       138.30  ...      NaN      NaN
# 1          NaN      29.65       125.92       292.81  ...      NaN      NaN
# 2          NaN      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          NaN      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %%
df1 = df.groupby('workout_type').workout_type.agg(count = 'count')
df1
# Out:
#                  count
# workout_type
# Cricket             93
# Freestyle           96
# Indoor Cycling      80
# Open Water          91
# Outdoor Cycling     85
# Outdoor Running     81
# Pool Swimming       94
# Trail Run           90
# Treadmill           98
# Trekking            94
# Walking             98

# %%
plt.pie(x=df.groupby('workout_type').workout_type.agg('count'),labels = df.groupby('workout_type').workout_type.agg('count').index, autopct='%.0f%%' )

plt.show()

# %%
#Create the bar graph by gathering the data first
x=df.groupby('workout_type').workout_type.agg('count')
labels = df.groupby('workout_type').workout_type.agg('count').index

#Now we should resize everything to make it better to look at
fig, ax = plt.subplots(figsize=(15, 30)) 
ax.pie(x, labels=labels)
plt.legend(labels,loc=2)
ax.set_title("Types of Workouts")
# Out:
# Text(0.5, 1.0, 'Work Out Type')

# %% [markdown]
# One of the things that a Mosaic graph can show that a bar or pie chart can't is the different variables in the single object. The mosaic graph can use the length to represent one thing and the width to represent another thing. That's why the graph looks so odd. The bar and pie charts cannot do that, so that's why they look the same width-wise.
