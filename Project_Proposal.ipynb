# %% [markdown]
# <a href="https://colab.research.google.com/github/maggiejohnson20/DataProcessingAndVisualization/blob/main/Project_Proposal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Gas Prices Throughout the United States Project Proposal**

# %% [markdown]
# What has been all over the internet lately? What has everyone been complaining about lately? What are strangers usually talking about to break the awkward silence? Gas prices.
#
# Everytime we turn on the news, there's always an article about the rise of gas prices. Even when we check our social media accounts, there's usually an article about gas prices.
#
# I came across the AAA website and it had the image below on the website. I would like to recreate this image.

# %% [markdown]
# ![AAA Gas Prices throughout the US.png](data:image/png;base64,...)

# %% [markdown]
# To get a better look at the image and the website, here is a link!
# [AAA Gas Prices](https://gasprices.aaa.com/)

# %% [markdown]
# The reason why I'm interested in working on this topic is because it's an issue around the entire country. I mainly want to see what countries have the highest/lowest gas prices. I like the way the graph is easy to read. I also want to challenge myself to try to recreate this.
#
# I know it'll be very challenging to recreate because the visualization is perfect and it will be hard to make it just like that. I want to try to replicate this visualization as close as possible to the original.
