# %% [markdown]
# <a href="https://colab.research.google.com/github/maggiejohnson20/DataProcessingAndVisualization/blob/main/Quiz19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Let's grab the data frame.

# %%
import pandas as pa

df = pa.read_csv("https://raw.githubusercontent.com/nurfnick/Data_Viz/main/AB_NYC_2019.csv") 

df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df2=df[~df.isnull().any(axis = 1)]
df2.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %% [markdown]
# Now since that's clean, let's find the total number of nulls are in each columns.

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# Here's the total number of nulls in the data frame.

# %%
df.isna().sum().sum()
# Out:
# 20141

# %% [markdown]
# Let's get more specific, we will find the total number of nulls in the last_review column

# %%
df['last_review'].isna().sum()
# Out:
# 10052

# %% [markdown]
# Now let's assign a value to the entire data frame.

# %%
df2 = pa.read_csv("https://raw.githubusercontent.com/nurfnick/Data_Viz/main/AB_NYC_2019.csv") 
df2.fillna(value = 2000, inplace = True) 
df2.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df3 = pa.read_csv("https://raw.githubusercontent.com/nurfnick/Data_Viz/main/AB_NYC_2019.csv") 
df3.fillna(value = 2000, #The fillna() method replaces the NULL values with any specified value, I am assigning 8888 in this case
          inplace =True) 
df3.host_name
# Out:
# 0                 John
# 1             Jennifer
# 2            Elisabeth
# 3          LisaRoxanne
# 4                Laura
#              ...
# 48890          Sabrina
# 48891          Marisol
# 48892    Ilgar & Aysel
# 48893              Taz
# 48894       Christophe
# Name: host_name, Length: 48895, dtype: object

# %% [markdown]
# We need to see if it's actually assigned.

# %%
df3.host_name.loc[df3['host_name']== 2000]
# Out:
# 360      2000
# 2700     2000
# 5745     2000
# 6075     2000
# 6582     2000
# 8163     2000
# 8257     2000
# 8852     2000
# 9138     2000
# 9817     2000
# 14040    2000
# 14631    2000
# 15174    2000
# 19565    2000
# 27777    2000
# 27962    2000
# 28042    2000
# 28274    2000
# 30570    2000
# 32193    2000
# 38992    2000
# Name: host_name, dtype: object

# %% [markdown]
# It's time to work on part two of the quiz. Let's pull the data frame and display the number of nulls in the 'name' column

# %%
dfname=pa.read_csv("https://raw.githubusercontent.com/nurfnick/Data_Viz/main/AB_NYC_2019.csv") 
dfname['name'].isna().sum()
# Out:
# 16

# %% [markdown]
# Nice, there's only 16, let's get rid of them!
#
# We need to use the abc to fill up the NaN values

# %%
dfname.fillna(value = 'abc', inplace =True)
dfname.loc[dfname['name'] == 'abc']
# Out:
#              id name   host_id host_name neighbourhood_group  \
# 2854    1615764  abc   6676776     Peter           Manhattan
# 3703    2232600  abc  11395220      Anna           Manhattan
# 5775    4209595  abc  20700823     Jesse           Manhattan
# 5975    4370230  abc  22686810   Michaël           Manhattan
# 6269    4581788  abc  21600904     Lucie            Brooklyn
# 6567    4756856  abc   1832442  Carolina            Brooklyn
# 6605    4774658  abc  24625694      Josh           Manhattan
# 8841    6782407  abc  31147528  Huei-Yin            Brooklyn
# 11963   9325951  abc  33377685  Jonathan           Manhattan
# 12824   9787590  abc  50448556    Miguel           Manhattan
# 13059   9885866  abc  37306329  Juliette           Manhattan
# 13401  10052289  abc  49522403   Vanessa            Brooklyn
# 15819  12797684  abc  69715276       Yan           Manhattan
# 16071  12988898  abc  71552588    Andrea               Bronx
# ...

# %% [markdown]
# Let's see if it worked...

# %%
dfname['name'].isna().sum()
# Out:
# 0
